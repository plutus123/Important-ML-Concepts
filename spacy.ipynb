# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
nlp

# %%
with open("jess302.txt","r") as f:
    text=f.read()

# %%
print(text)
# Out:
# Chapter II
#
# Nationalism in India
# As you have seen, modern nationalism in Europe came to be
# associated with the formation of nation-states. It also meant a change
# in people’s understanding of who they were, and what defined their
# identity and sense of belonging. New symbols and icons, new songs
# and ideas forged new links and redefined the boundaries of
# communities. In most countries the making of this new national
# identity was a long process. How did this consciousness emerge
# in India?
# In India and as in many other colonies, the growth of modern
# nationalism is intimately connected to the anti-colonial movement.
# People began discovering their unity in the process of their struggle
# with colonialism. The sense of being oppressed under colonialism
# provided a shared bond that tied many different groups together.
# But each class and group felt the effects of colonialism differently,
# their experiences were varied, and their notions of freedom were
# ...

# %%
doc = nlp(text)

# %%
print(doc)
# Out:
# Chapter II
#
# Nationalism in India
# As you have seen, modern nationalism in Europe came to be
# associated with the formation of nation-states. It also meant a change
# in people’s understanding of who they were, and what defined their
# identity and sense of belonging. New symbols and icons, new songs
# and ideas forged new links and redefined the boundaries of
# communities. In most countries the making of this new national
# identity was a long process. How did this consciousness emerge
# in India?
# In India and as in many other colonies, the growth of modern
# nationalism is intimately connected to the anti-colonial movement.
# People began discovering their unity in the process of their struggle
# with colonialism. The sense of being oppressed under colonialism
# provided a shared bond that tied many different groups together.
# But each class and group felt the effects of colonialism differently,
# their experiences were varied, and their notions of freedom were
# ...

# %%
print(len(text))
print(len(doc))
# Out:
# 53405
# 10841

# %%
for i in text[:10]:
    print(i)
# Out:
# C
# h
# a
# p
# t
# e
# r
#
# I
# I

# %%
for i in doc[:20]:
    print(i)
# Out:
# Chapter
# II
#
#
#
# Nationalism
# in
# India
#
#
# As
# you
# have
# seen
# ,
# modern
# nationalism
# in
# Europe
# came
# to
# be

# %%
for i in text.split()[:20]:
    print(i)
# Out:
# Chapter
# II
# Nationalism
# in
# India
# As
# you
# have
# seen,
# modern
# nationalism
# in
# Europe
# came
# to
# be
# associated
# with
# the
# formation

# %%
for sent in doc[:60].sents:
    print(sent)
# Out:
# Chapter II
#
# Nationalism in India
# As you have seen, modern nationalism in Europe came to be
# associated with the formation of nation-states.
# It also meant a change
# in people’s understanding of who they were, and what defined their
# identity and sense of belonging.
# New symbols and icons, new songs
# and ideas forged new links and redefined the boundaries of
# communities.

# %%
sentence1=list(doc.sents)[0]
sentence1
# Out:
# Chapter II
#
# Nationalism in India
# As you have seen, modern nationalism in Europe came to be
# associated with the formation of nation-states.

# %%
token1 = sentence1[5]
token1
# Out:
# India

# %%
token1.text
# Out:
# 'India'

# %%
token1.left_edge
# Out:
# India

# %%
token1.right_edge

# %%
token1.ent_type
# Out:
# 384

# %%
token1.ent_type_
# Out:
# 'GPE'

# %%
token1.ent_iob_
# Out:
# 'B'

# %%
token1.lemma_
# Out:
# 'India'

# %%
token1.morph
# Out:
# Number=Sing

# %%
token1.pos_
# Out:
# 'PROPN'

# %%
token1.dep_
# Out:
# 'pobj'

# %%
token1.lang_
# Out:
# 'en'

# %%
txt="Mike enjoys playing football."
doc2=nlp(txt)

# %%
doc2
# Out:
# Mike enjoys playing football.

# %%
for token in doc2:
    print(token.text , token.pos_ , token.dep_)
# Out:
# Mike PROPN nsubj
# enjoys VERB ROOT
# playing VERB xcomp
# football NOUN dobj
# . PUNCT punct

# %%
from spacy import displacy
displacy.render(doc2 , style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1a5a74a89b6a45bdad79b31e9693575b-0" class="displacy" width="750" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mike</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">enjoys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
# ...

# %%
for ent in doc.ents:
    print(ent.text , ent.label_)
# Out:
# Chapter II LAW
# India GPE
# Europe LOC
# India GPE
# India GPE
# Congress ORG
# Mahatma Gandhi PERSON
# one CARDINAL
# India GPE
# India GPE
# India GPE
# the first decade of the twentieth century DATE
# the 1920s DATE
# NonCooperation ORG
# Congress ORG
# Fig PERSON
# 1 CARDINAL
# 6 April 1919 DATE
# 29 CARDINAL
# 2023-24 DATE
# The First World War EVENT
# Non-Cooperation ORG
# the years after DATE
# 1919 DATE
# First ORDINAL
# years DATE
# between 1913 and 1918 DATE
# 1918-19 and 1920-21 DATE
# India GPE
# 1921 DATE
# 12 CARDINAL
# 13 million CARDINAL
# Forced NORP
# 1.1 CARDINAL
# The Idea of Satyagraha
#
#  WORK_OF_ART
# India GPE
# the Contemporary World ORG
# Mahatma Gandhi PERSON
# India GPE
# January 1915 DATE
# South Africa GPE
# Fig PERSON
# 2 CARDINAL
# Indian NORP
# South
# Africa GPE
# Volksrust ORG
# 6 CARDINAL
# November 1913 DATE
# Mahatma Gandhi PERSON
# Newcastle GPE
# Transvaal LOC
# Gandhiji PERSON
# thousands CARDINAL
# 30 CARDINAL
# 2023-24 DATE
# India GPE
# ...

# %%
displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chapter II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# <br><br>Nationalism in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>As you have seen, modern nationalism in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
# ...

# %%
nlp = spacy.load("en_core_web_md")

# %%
with open("jess302.txt","r") as f:
    text=f.read()

# %%
doc=nlp(text)
doc
# Out:
# Chapter II
#
# Nationalism in India
# As you have seen, modern nationalism in Europe came to be
# associated with the formation of nation-states. It also meant a change
# in people’s understanding of who they were, and what defined their
# identity and sense of belonging. New symbols and icons, new songs
# and ideas forged new links and redefined the boundaries of
# communities. In most countries the making of this new national
# identity was a long process. How did this consciousness emerge
# in India?
# In India and as in many other colonies, the growth of modern
# nationalism is intimately connected to the anti-colonial movement.
# People began discovering their unity in the process of their struggle
# with colonialism. The sense of being oppressed under colonialism
# provided a shared bond that tied many different groups together.
# But each class and group felt the effects of colonialism differently,
# their experiences were varied, and their notions of freedom were
# ...

# %%
sentence1=list(doc.sents)[0]
print(sentence1)
# Out:
# Chapter II
#
# Nationalism in India
# As you have seen, modern nationalism in Europe came to be
# associated with the formation of nation-states.

# %%
import numpy as np
your_word="country"
ms=nlp.vocab.vectors.most_similar(
                                np.asarray([nlp.vocab.vectors[nlp.vocab.strings[your_word]]]),n=10)
words=[nlp.vocab.strings[w] for w in ms[0][0]]
distances= ms[2]
print(words)
# Out:
# ['country—0,467', 'nationâ\x80\x99s', 'countries-', 'continente', 'Carnations', 'pastille', 'бесплатно', 'Argents', 'Tywysogion', 'Teeters']

# %%
doc1=nlp("I love burger with fries")
doc2=nlp("Fast food tastes very good")

# %%
print(doc1 , "<->" , doc2 , doc1.similarity(doc2))
# Out:
# I love burger with fries <-> Fast food tastes very good 0.5278100895025931

# %%
nlp = spacy.blank("en")
print(nlp)

# %%
nlp.add_pipe("sentencizer")

# %%
import requests
from bs4 import BeautifulSoup
s = requests.get("https://ocw.mit.edu/ans7870/6/6.006/s08/lecturenotes/files/t8.shakespeare.txt")
soup = BeautifulSoup(s.content).text.replace("-\n", "").replace("\n", " ")
nlp.max_length = 5278439

# %%
nlp.analyze_pipes()

# %%
nlp1 = spacy.load("en_core_web_sm")

# %%
nlp1.analyze_pipes()

# %%
nlp=spacy.load("en_core_web_sm")
text="West Chesternfieldville was referenced in Mr. Deeds."

# %%
doc=nlp(text)

# %%
for ent in doc.ents:
    print(ent.text , ent.label_)
# Out:
# West Chesternfieldville PERSON
# Deeds PERSON

# %%
ruler = nlp.add_pipe("entity_ruler")

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False},
# ...

# %%
patterns=[
    {"label":"GPE","pattern":"West Chesternfieldville"}    
]

# %%
ruler.add_patterns(patterns)

# %%
doc2=nlp(text)
for ent in doc2.ents:
    print(ent.text , ent.label_)
# Out:
# West Chesternfieldville PERSON
# Deeds PERSON

# %%
nlp2=spacy.load("en_core_web_sm")

# %%
ruler = nlp2.add_pipe("entity_ruler",before="ner")

# %%
ruler.add_patterns(patterns)

# %%
doc = nlp2(text)

# %%
for ent in doc.ents:
    print(ent.text , ent.label_)
# Out:
# West Chesternfieldville GPE
# Deeds PERSON

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False},
# ...

# %%
nlp3=spacy.load("en_core_web_sm")
ruler=nlp3.add_pipe("entity_ruler",before="ner")

# %%
patterns=[
    {"label":"GPE","pattern":"West Chesternfieldville"},
    {"label":"FILM","pattern":"Mr. Deeds"} 
]

# %%
ruler.add_patterns(patterns)

# %%
doc3=nlp3(text)

# %%
for ent in doc3.ents:
    print(ent.text , ent.label_)
# Out:
# West Chesternfieldville GPE
# Mr. Deeds FILM

# %%
#toponym resolution -> Mr Deeds can sometimes even be the name of a person
#this is the limitation of every ML model

# %%
import spacy
from spacy.matcher import Matcher

# %%
nlp= spacy.load("en_core_web_sm")

# %%
matcher = Matcher(nlp.vocab)
pattern = [{"LIKE_EMAIL":True}]
matcher.add("EMAIL_ADDRESS",[pattern])

# %%
text="This is my email address: vishwas.mishra1234@gmail.com"
doc=nlp(text)
matches=matcher(doc)

# %%
print(matches) # [(Lexeme , start_token , end_token)]
# Out:
# [(16571425990740197027, 6, 7)]

# %%
print(nlp.vocab[matches[0][0]].text)
# Out:
# EMAIL_ADDRESS

# %%
with open("jess302.txt","r") as f:
    text=f.read()

# %%
print(text)
# Out:
# Chapter II
#
# Nationalism in India
# As you have seen, modern nationalism in Europe came to be
# associated with the formation of nation-states. It also meant a change
# in people’s understanding of who they were, and what defined their
# identity and sense of belonging. New symbols and icons, new songs
# and ideas forged new links and redefined the boundaries of
# communities. In most countries the making of this new national
# identity was a long process. How did this consciousness emerge
# in India?
# In India and as in many other colonies, the growth of modern
# nationalism is intimately connected to the anti-colonial movement.
# People began discovering their unity in the process of their struggle
# with colonialism. The sense of being oppressed under colonialism
# provided a shared bond that tied many different groups together.
# But each class and group felt the effects of colonialism differently,
# their experiences were varied, and their notions of freedom were
# ...

# %%
nlp= spacy.load("en_core_web_sm")

# %%
matcher = Matcher(nlp.vocab)
pattern=[{"POS":"PROPN"}]  # Part of Speech that belongs to propernoun
matcher.add("PROPER_NOUN",[pattern])
doc=nlp(text)
matches=matcher(doc)
print(len(matches))
for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
# Out:
# 1068
# (451313080118390996, 1, 2) II
# (451313080118390996, 3, 4) Nationalism
# (451313080118390996, 5, 6) India
# (451313080118390996, 15, 16) Europe
# (451313080118390996, 99, 100) India
# (451313080118390996, 103, 104) India
# (451313080118390996, 194, 195) Congress
# (451313080118390996, 196, 197) Mahatma
# (451313080118390996, 197, 198) Gandhi
# (451313080118390996, 220, 221) Nationalism

# %%
matcher = Matcher(nlp.vocab)
pattern=[{"POS":"PROPN", "OP":"+"}]  # Part of Speech that belongs to propernoun
matcher.add("PROPER_NOUN",[pattern])
doc=nlp(text)
matches=matcher(doc)
print(len(matches))
for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
# Out:
# 1463
# (451313080118390996, 1, 2) II
# (451313080118390996, 3, 4) Nationalism
# (451313080118390996, 5, 6) India
# (451313080118390996, 15, 16) Europe
# (451313080118390996, 99, 100) India
# (451313080118390996, 103, 104) India
# (451313080118390996, 194, 195) Congress
# (451313080118390996, 196, 197) Mahatma
# (451313080118390996, 196, 198) Mahatma Gandhi
# (451313080118390996, 197, 198) Gandhi

# %%
matcher = Matcher(nlp.vocab)
pattern=[{"POS":"PROPN", "OP":"+"}]  # Part of Speech that belongs to propernoun
matcher.add("PROPER_NOUN",[pattern],greedy="LONGEST")
doc=nlp(text)
matches=matcher(doc)
print(len(matches))
for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
# Out:
# 746
# (451313080118390996, 2769, 2773) Non-Cooperation Movement
# (451313080118390996, 4263, 4267) Non-Cooperation Movement
# (451313080118390996, 4292, 4296) Non-Cooperation Movement
# (451313080118390996, 7198, 7202) Second Round Table Conference
# (451313080118390996, 10614, 10618) Non-Cooperation Movement
# (451313080118390996, 10746, 10750) Non-Cooperation Movement
# (451313080118390996, 272, 275) Civil Disobedience Movements
# (451313080118390996, 347, 350) First World War
# (451313080118390996, 353, 356) Non-Cooperation
# (451313080118390996, 1801, 1804) First World War

# %%
matcher = Matcher(nlp.vocab)
pattern=[{"POS":"PROPN", "OP":"+"}]  # Part of Speech that belongs to propernoun
matcher.add("PROPER_NOUN",[pattern],greedy="LONGEST")
doc=nlp(text)
matches=matcher(doc)
matches.sort(key = lambda x:x[1])
print(len(matches))
for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
# Out:
# 746
# (451313080118390996, 1, 2) II
# (451313080118390996, 3, 4) Nationalism
# (451313080118390996, 5, 6) India
# (451313080118390996, 15, 16) Europe
# (451313080118390996, 99, 100) India
# (451313080118390996, 103, 104) India
# (451313080118390996, 194, 195) Congress
# (451313080118390996, 196, 198) Mahatma Gandhi
# (451313080118390996, 220, 221) Nationalism
# (451313080118390996, 223, 224) India

# %%
# Everytime ProperNoun is followed by a verb

# %%
matcher = Matcher(nlp.vocab)
pattern=[{"POS":"PROPN", "OP":"+"},{"POS":"VERB"}]  # Part of Speech that belongs to propernoun
matcher.add("PROPER_NOUN",[pattern],greedy="LONGEST")
doc=nlp(text)
matches=matcher(doc)
matches.sort(key = lambda x:x[1])
print(len(matches))
for match in matches[:10]:
    print(match, doc[match[1]:match[2]])
# Out:
# 70
# (451313080118390996, 15, 17) Europe came
# (451313080118390996, 196, 199) Mahatma Gandhi tried
# (451313080118390996, 282, 284) Congress sought
# (451313080118390996, 622, 625) Mahatma Gandhi returned
# (451313080118390996, 688, 690) Gandhiji arrested
# (451313080118390996, 812, 815) Mahatma Gandhi went
# (451313080118390996, 906, 909) Mahatma Gandhi wanted
# (451313080118390996, 1222, 1224) satyagraha emphasised
# (451313080118390996, 1339, 1342) Mahatma Gandhi believed
# (451313080118390996, 1438, 1440) Amritsar fired

# %%
nlp=spacy.load("en_core_web_sm")
doc=nlp("Britain is a place.Mary is a doctor.")

# %%
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Britain GPE
# Mary PERSON

# %%
from spacy.language import Language

# %%
@Language.component("remove_gpe")
def remove_gpe(doc):
    original_ents=list(doc.ents)
    for ent in doc.ents:
        if ent.label_=="GPE":
            original_ents.remove(ent)
    doc.ents=original_ents
    return (doc)

# %%
nlp.add_pipe("remove_gpe")
# Out:
# <function __main__.remove_gpe(doc)>

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False},
#   'remove_gpe': {'assigns': [],
#    'requires': [],
# ...

# %%
doc=nlp("Britain is a place.Mary is a doctor.")
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Mary PERSON

# %%
import re

# %%
text = "Paul Newman was an American actor, but Paul Hollywood is a British TV Host. The name Paul is quite common."

# %%
pattern=r"Paul [A-Z]\w+"

# %%
matches=re.finditer(pattern,text)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 11), match='Paul Newman'>
# <re.Match object; span=(39, 53), match='Paul Hollywood'>

# %%
import spacy
from spacy.tokens import Span

# %%
nlp=spacy.blank("en")
doc=nlp(text)
original_ents=list(doc.ents)
mwt_ents=[]
for match in re.finditer(pattern,doc.text):
    start , end =match.span()
    span=doc.char_span(start,end)
    if span is not None:
        mwt_ents.append((span.start,span.end,span.text))
for ent in mwt_ents:
    start,end,name=ent
    per_ent=Span(doc,start,end,label="PERSON")
    original_ents.append(per_ent)
doc.ents=original_ents
for ent in doc.ents:
    print(ent.text , ent.label_)
# Out:
# Paul Newman PERSON
# Paul Hollywood PERSON

# %%
mwt_ents
# Out:
# [(0, 2, 'Paul Newman'), (8, 10, 'Paul Hollywood')]

# %%
from spacy.language import Language
@Language.component("paul_ner")
def paul_ner(doc):
    pattern=r"Paul [A-Z]\w+"
    original_ents=list(doc.ents)
    mwt_ents=[]
    for match in re.finditer(pattern,doc.text):
        start , end =match.span()
        span=doc.char_span(start,end)
    if span is not None:
        mwt_ents.append((span.start,span.end,span.text))
    for ent in mwt_ents:
        start,end,name=ent
        per_ent=Span(doc,start,end,label="PERSON")
        original_ents.append(per_ent)
    doc.ents=original_ents
    return (doc)

# %%
nlp2=spacy.blank("en")
nlp2.add_pipe("paul_ner")
# Out:
# <function __main__.paul_ner(doc)>

# %%
doc2=nlp2(text)
print(doc2.ents)
# Out:
# (Paul Hollywood,)

# %%
from spacy.language import Language
from spacy.util import filter_spans
@Language.component("cinema_ner")
def cinema_ner(doc):
    pattern=r"Hollywood"
    original_ents=list(doc.ents)
    mwt_ents=[]
    for match in re.finditer(pattern,doc.text):
        start , end =match.span()
        span=doc.char_span(start,end)
    if span is not None:
        mwt_ents.append((span.start,span.end,span.text))
    for ent in mwt_ents:
        start,end,name=ent
        per_ent=Span(doc,start,end,label="CINEMA")
        original_ents.append(per_ent)
    filtered=filter_spans(original_ents)
    doc.ents=filtered
    return (doc)

# %%
nlp3=spacy.load("en_core_web_sm")
nlp3.add_pipe("cinema_ner")
# Out:
# <function __main__.cinema_ner(doc)>

# %%
doc3=nlp3(text)
for ent in doc3.ents:
    print(ent.text , ent.label_)
# Out:
# Paul Newman PERSON
# American NORP
# Paul Hollywood PERSON
# British NORP
# Paul PERSON
